# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../dataset/cleaned_GLD.csv')

# %%
# Check head
df.head()
# Out:
#        Date   Adj Close       Close        High         Low        Open  \
# 0  1/2/2019  121.330002  121.330002  121.750000  120.879997  121.349998
# 1  1/3/2019  122.430000  122.430000  122.459999  121.730003  121.779999
# 2  1/4/2019  121.440002  121.440002  121.599998  120.690002  121.320000
# 3  1/7/2019  121.860001  121.860001  122.220001  121.570000  122.160004
# 4  1/8/2019  121.529999  121.529999  121.709999  121.059998  121.150002
#
#      Volume
# 0  12776200
# 1  15440800
# 2  13334000
# 3   7473600
# 4   7643100

# %%
# Check tail
df.tail()
# Out:
#             Date   Adj Close       Close        High         Low        Open  \
# 1467  10/30/2024  257.500000  257.500000  257.709992  255.910004  256.760010
# 1468  10/31/2024  253.509995  253.509995  255.600006  252.199997  255.520004
# 1469   11/1/2024  252.470001  252.470001  254.860001  252.440002  254.330002
# 1470   11/4/2024  252.830002  252.830002  253.580002  252.270004  253.320007
# 1471   11/5/2024  253.399994  253.399994  253.990005  252.410004  253.779999
#
#        Volume
# 1467  6386200
# 1468  9930800
# 1469  6473000
# 1470  4581400
# 1471  6029900

# %%
# Calculate the statistical metrics for each relevant column
metrics = {
    "Mean": df[["Close", "Volume", "Open", "High", "Low", "Adj Close"]].mean(),
    "Median": df[["Close", "Volume", "Open", "High", "Low", "Adj Close"]].median(),
    "Mode": df[["Close", "Volume", "Open", "High", "Low", "Adj Close"]].mode().iloc[0],  # taking first mode in case of multiple
    "Range": df[["Close", "Volume", "Open", "High", "Low", "Adj Close"]].max() - df[["Close", "Volume", "Open", "High", "Low", "Adj Close"]].min(),
    "Variance": df[["Close", "Volume", "Open", "High", "Low", "Adj Close"]].var(),
    "Standard Deviation": df[["Close", "Volume", "Open", "High", "Low", "Adj Close"]].std()
}

# %%
# Convert the dictionary to a DataFrame for display
metrics_df = pd.DataFrame(metrics)

# %%
# Set display options to prevent line breaks in the output
pd.set_option('display.width', 1000)        # Set the display width to a large enough value
pd.set_option('display.max_columns', None)  # Ensure all columns are displayed


print(metrics_df)
# Out:
#                    Mean        Median          Mode         Range      Variance  Standard Deviation
# Close      1.708175e+02  1.701000e+02  1.786400e+02  1.375600e+02  7.176352e+02        2.678871e+01
# Volume     8.689538e+06  7.454050e+06  5.389300e+06  4.591120e+07  2.326418e+13        4.823295e+06
# Open       1.708126e+02  1.703050e+02  1.758300e+02  1.370900e+02  7.172864e+02        2.678220e+01
# High       1.715538e+02  1.707000e+02  1.234000e+02  1.376000e+02  7.242076e+02        2.691111e+01
# Low        1.700232e+02  1.694350e+02  1.685200e+02  1.363700e+02  7.085389e+02        2.661839e+01
# Adj Close  1.708175e+02  1.701000e+02  1.786400e+02  1.375600e+02  7.176352e+02        2.678871e+01

# %% [markdown]
# # Histogram Chart

# %%
# Plotting a histogram of gold prices over time using the "Price" column
plt.figure(figsize=(15, 6))
plt.hist(df["Close"], bins=50, edgecolor="black", alpha=0.6, color='grey')
plt.title("Histogram chart of gold price")
plt.xlabel("Gold Price")
plt.ylabel("Frequency")
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# # Box Plot

# %%
plt.figure(figsize=(15, 6))

data = df['Close']

plt.boxplot(data, labels=['Box Plot of Gold Price'], patch_artist=True, boxprops=dict(facecolor='skyblue', color='blue'),)


plt.ylabel('Close')
# Out:
# C:\Users\yashi\AppData\Local\Temp\ipykernel_6604\948783023.py:5: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(data, labels=['Box Plot of Gold Price'], patch_artist=True, boxprops=dict(facecolor='skyblue', color='blue'),)
# Text(0, 0.5, 'Close')

# %% [markdown]
# # Scatter Plot

# %%
# Convert 'Date' column to datetime format
df['Date'] = pd.to_datetime(df['Date'])

# Plotting the scatter plot
plt.figure(figsize=(15, 6))
plt.scatter(df['Date'], df['Close'], s=5, alpha=0.6)  # Using small points for scatter plot effect
plt.title("Gold Prices Over Time (Scatter Plot)")
plt.xlabel("Date")
plt.ylabel("Price (USD)")
plt.grid(True)
plt.show()
