# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../dataset/cleaned_NEM.csv')

# %%
# Check head
df.head()
# Out:
#        Date  Adj Close      Close       High        Low       Open   Volume
# 0  1/2/2019  28.435770  34.480000  34.779999  33.939999  34.450001  4094800
# 1  1/3/2019  28.353298  34.380001  34.869999  34.049999  34.740002  5763200
# 2  1/4/2019  28.353298  34.380001  34.490002  33.279999  33.910000  8622600
# 3  1/7/2019  28.015163  33.970001  34.930000  33.799999  34.669998  4868600
# 4  1/8/2019  28.097637  34.070000  34.080002  33.389999  33.630001  6457200

# %%
# Check tail
df.tail()
# Out:
#             Date  Adj Close      Close       High        Low       Open  \
# 1467  10/30/2024  46.939999  46.939999  47.580002  46.509998  47.439999
# 1468  10/31/2024  45.439999  45.439999  46.450001  45.180000  46.349998
# 1469   11/1/2024  45.259998  45.259998  46.009998  45.090000  45.389999
# 1470   11/4/2024  45.759998  45.759998  45.889999  45.130001  45.389999
# 1471   11/5/2024  46.000000  46.000000  46.130001  45.669998  45.799999
#
#         Volume
# 1467  11956500
# 1468  13809400
# 1469  11049000
# 1470   8656200
# 1471   6789100

# %%
# Calculate the statistical metrics for each relevant column
metrics = {
    "Mean": df[["Close", "Volume", "Open", "High", "Low", "Adj Close"]].mean(),
    "Median": df[["Close", "Volume", "Open", "High", "Low", "Adj Close"]].median(),
    "Mode": df[["Close", "Volume", "Open", "High", "Low", "Adj Close"]].mode().iloc[0],  # taking first mode in case of multiple
    "Range": df[["Close", "Volume", "Open", "High", "Low", "Adj Close"]].max() - df[["Close", "Volume", "Open", "High", "Low", "Adj Close"]].min(),
    "Variance": df[["Close", "Volume", "Open", "High", "Low", "Adj Close"]].var(),
    "Standard Deviation": df[["Close", "Volume", "Open", "High", "Low", "Adj Close"]].std()
}

# %%
# Convert the dictionary to a DataFrame for display
metrics_df = pd.DataFrame(metrics)

# %%
# Set display options to prevent line breaks in the output
pd.set_option('display.width', 1000)        # Set the display width to a large enough value
pd.set_option('display.max_columns', None)  # Ensure all columns are displayed


print(metrics_df)
# Out:
#                    Mean        Median          Mode         Range      Variance  Standard Deviation
# Close      4.993968e+01  4.733500e+01  3.844000e+01  5.556000e+01  1.443197e+02        1.201331e+01
# Volume     8.583277e+06  7.336200e+06  5.091600e+06  9.632600e+07  3.045929e+13        5.518993e+06
# Open       4.992462e+01  4.724500e+01  3.803000e+01  5.596000e+01  1.443274e+02        1.201363e+01
# High       5.060940e+01  4.810000e+01  3.777000e+01  5.631000e+01  1.487469e+02        1.219619e+01
# Low        4.924433e+01  4.655500e+01  3.380000e+01  5.568000e+01  1.395845e+02        1.181459e+01
# Adj Close  4.532521e+01  4.465601e+01  3.735589e+01  5.254740e+01  1.127876e+02        1.062015e+01

# %% [markdown]
# # Histogram Chart

# %%
# Plotting a histogram of gold prices over time using the "Price" column
plt.figure(figsize=(15, 6))
plt.hist(df["Close"], bins=50, edgecolor="black", alpha=0.6, color='grey')
plt.title("Histogram chart of gold price")
plt.xlabel("Gold Price")
plt.ylabel("Frequency")
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# # Box plot

# %%
plt.figure(figsize=(15, 6))

data = df['Close']

plt.boxplot(data, labels=['Box Plot of Gold Price'], patch_artist=True, boxprops=dict(facecolor='skyblue', color='blue'),)


plt.ylabel('Price')
# Out:
# C:\Users\yashi\AppData\Local\Temp\ipykernel_6368\2478158420.py:5: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(data, labels=['Box Plot of Gold Price'], patch_artist=True, boxprops=dict(facecolor='skyblue', color='blue'),)
# Text(0, 0.5, 'Price')

# %% [markdown]
# # Scatter Plot

# %%
# Convert 'Date' column to datetime format
df['Date'] = pd.to_datetime(df['Date'])

# Plotting the scatter plot
plt.figure(figsize=(15, 6))
plt.scatter(df['Date'], df['Close'], s=5, alpha=0.6)  # Using small points for scatter plot effect
plt.title("Gold Prices Over Time (Scatter Plot)")
plt.xlabel("Date")
plt.ylabel("Price (USD)")
plt.grid(True)
plt.show()
