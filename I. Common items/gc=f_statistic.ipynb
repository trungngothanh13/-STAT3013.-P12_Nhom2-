# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../dataset/cleaned_gc=f.csv')

# %%
df = df.drop(columns=['Unnamed: 0'])

# %%
# Check head
df.head()
# Out:
#          Date    Adj Close        Close         High          Low  \
# 0  2019-01-02  1281.000000  1281.000000  1286.000000  1277.599976
# 1  2019-01-03  1291.800049  1291.800049  1292.000000  1286.699951
# 2  2019-01-04  1282.699951  1282.699951  1294.199951  1275.300049
# 3  2019-01-07  1286.800049  1286.800049  1286.800049  1286.599976
# 4  2019-01-08  1283.199951  1283.199951  1283.199951  1278.199951
#
#           Open  Volume
# 0  1286.000000     149
# 1  1286.800049      10
# 2  1294.199951      34
# 3  1286.800049       2
# 4  1280.500000      54

# %%
# Check tail
df.tail()
# Out:
#             Date    Adj Close        Close         High          Low  \
# 1467  2024-10-30  2788.500000  2788.500000  2789.000000  2774.600098
# 1468  2024-10-31  2738.300049  2738.300049  2787.500000  2733.500000
# 1469  2024-11-01  2738.600098  2738.600098  2756.000000  2734.199951
# 1470  2024-11-04  2736.100098  2736.100098  2737.100098  2736.100098
# 1471  2024-11-05  2740.300049  2740.300049  2743.899902  2740.300049
#
#              Open  Volume
# 1467  2774.600098     231
# 1468  2787.399902     849
# 1469  2745.500000     109
# 1470  2736.500000      16
# 1471  2743.000000      16

# %% [markdown]
# # Descriptive Statistical

# %%
# Calculate the statistical metrics for each relevant column
metrics = {
    "Mean": df[["Close", "Volume", "Open", "High", "Low", "Adj Close"]].mean(),
    "Median": df[["Close", "Volume", "Open", "High", "Low", "Adj Close"]].median(),
    "Mode": df[["Close", "Volume", "Open", "High", "Low", "Adj Close"]].mode().iloc[0],  # taking first mode in case of multiple
    "Range": df[["Close", "Volume", "Open", "High", "Low", "Adj Close"]].max() - df[["Close", "Volume", "Open", "High", "Low", "Adj Close"]].min(),
    "Variance": df[["Close", "Volume", "Open", "High", "Low", "Adj Close"]].var(),
    "Standard Deviation": df[["Close", "Volume", "Open", "High", "Low", "Adj Close"]].std()
}
# Out:
#          Adj Close        Close         High          Low         Open  \
# count  1472.000000  1472.000000  1472.000000  1472.000000  1472.000000
# mean   1828.861139  1828.861139  1837.540762  1820.015013  1828.595924
# std     297.361527   297.361527   298.816020   295.761726   297.093429
# min    1269.300049  1269.300049  1269.800049  1266.000000  1266.400024
# 25%    1699.200012  1699.200012  1710.250031  1684.875030  1696.774994
# 50%    1820.750000  1820.750000  1828.799988  1813.099976  1820.150024
# 75%    1952.149994  1952.149994  1960.075012  1940.699951  1948.674988
# max    2788.500000  2788.500000  2789.000000  2774.600098  2787.399902
#
#               Volume
# count    1472.000000
# mean     4652.360734
# std     25931.409940
# min         0.000000
# 25%        61.000000
# 50%       210.500000
# 75%       610.250000
# max    346362.000000

# %%
# Convert the dictionary to a DataFrame for display
metrics_df = pd.DataFrame(metrics)

# %%
# Set display options to prevent line breaks in the output
pd.set_option('display.width', 1000)        # Set the display width to a large enough value
pd.set_option('display.max_columns', None)  # Ensure all columns are displayed


print(metrics_df)
# Out:
#                   Mean       Median         Mode          Range      Variance  Standard Deviation
# Close      1828.861139  1820.750000  1815.900024    1519.199951  8.842388e+04          297.361527
# Volume     4652.360734   210.500000     1.000000  346362.000000  6.724380e+08        25931.409940
# Open       1828.595924  1820.150024  1794.300049    1520.999878  8.826451e+04          297.093429
# High       1837.540762  1828.799988  1813.500000    1519.199951  8.929101e+04          298.816020
# Low        1820.015013  1813.099976  1463.099976    1508.600098  8.747500e+04          295.761726
# Adj Close  1828.861139  1820.750000  1815.900024    1519.199951  8.842388e+04          297.361527

# %% [markdown]
# # Histogram Chart

# %%
# Plotting a histogram of gold prices over time using the "Price" column
plt.figure(figsize=(15, 6))
plt.hist(df["Close"], bins=50, edgecolor="black", alpha=0.6, color='grey')
plt.title("Histogram chart of gold price")
plt.xlabel("Gold Price")
plt.ylabel("Frequency")
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# # Box plot

# %%
plt.figure(figsize=(15, 6))

data = df['Close']

plt.boxplot(data, labels=['Box Plot of Gold Price'], patch_artist=True, boxprops=dict(facecolor='skyblue', color='blue'),)


plt.ylabel('Price')
# Out:
# C:\Users\yashi\AppData\Local\Temp\ipykernel_31004\2478158420.py:5: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(data, labels=['Box Plot of Gold Price'], patch_artist=True, boxprops=dict(facecolor='skyblue', color='blue'),)
# Text(0, 0.5, 'Price')

# %% [markdown]
# # Scatter Plot

# %%
# Convert 'Date' column to datetime format
df['Date'] = pd.to_datetime(df['Date'])

# Plotting the scatter plot
plt.figure(figsize=(10, 6))
plt.scatter(df['Date'], df['Close'], s=5, alpha=0.6)  # Using small points for scatter plot effect
plt.title("Gold Prices Over Time (Scatter Plot)")
plt.xlabel("Date")
plt.ylabel("Price (USD)")
plt.grid(True)
plt.show()
