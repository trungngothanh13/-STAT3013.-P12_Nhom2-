# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../dataset/cleaned_GLD.csv')

# %%
df = df.drop(columns=['Unnamed: 0'])

# %%
# Check head
df.head()
# Out:
#          Date   Adj Close       Close        High         Low        Open  \
# 0  2019-01-02  121.330002  121.330002  121.750000  120.879997  121.349998
# 1  2019-01-03  122.430000  122.430000  122.459999  121.730003  121.779999
# 2  2019-01-04  121.440002  121.440002  121.599998  120.690002  121.320000
# 3  2019-01-07  121.860001  121.860001  122.220001  121.570000  122.160004
# 4  2019-01-08  121.529999  121.529999  121.709999  121.059998  121.150002
#
#      Volume
# 0  12776200
# 1  15440800
# 2  13334000
# 3   7473600
# 4   7643100

# %%
# Check tail
df.tail()
# Out:
#             Date   Adj Close       Close        High         Low        Open  \
# 1364  2024-06-04  215.270004  215.270004  216.240005  214.199997  216.240005
# 1365  2024-06-05  217.820007  217.820007  218.080002  215.929993  216.690002
# 1366  2024-06-06  219.429993  219.429993  219.970001  218.100006  218.360001
# 1367  2024-06-07  211.600006  211.600006  215.190002  211.539993  215.070007
# 1368  2024-06-10  213.539993  213.539993  214.020004  212.759995  213.130005
#
#         Volume
# 1364   5509400
# 1365   5479200
# 1366   5283900
# 1367  12195100
# 1368   4219600

# %%
# Calculate the statistical metrics for each relevant column
metrics = {
    "Mean": df[["Close", "Volume", "Open", "High", "Low", "Adj Close"]].mean(),
    "Median": df[["Close", "Volume", "Open", "High", "Low", "Adj Close"]].median(),
    "Mode": df[["Close", "Volume", "Open", "High", "Low", "Adj Close"]].mode().iloc[0],  # taking first mode in case of multiple
    "Range": df[["Close", "Volume", "Open", "High", "Low", "Adj Close"]].max() - df[["Close", "Volume", "Open", "High", "Low", "Adj Close"]].min(),
    "Variance": df[["Close", "Volume", "Open", "High", "Low", "Adj Close"]].var(),
    "Standard Deviation": df[["Close", "Volume", "Open", "High", "Low", "Adj Close"]].std()
}

# %%
# Convert the dictionary to a DataFrame for display
metrics_df = pd.DataFrame(metrics)

# %%
# Set display options to prevent line breaks in the output
pd.set_option('display.width', 1000)        # Set the display width to a large enough value
pd.set_option('display.max_columns', None)  # Ensure all columns are displayed


print(metrics_df)
# Out:
#                    Mean        Median          Mode         Range      Variance  Standard Deviation
# Close      1.661920e+02  1.690000e+02  1.786400e+02  1.046200e+02  4.535243e+02        2.129611e+01
# Volume     8.868857e+06  7.574600e+06  5.389300e+06  4.591120e+07  2.422832e+13        4.922227e+06
# Open       1.661895e+02  1.688800e+02  1.758300e+02  1.051000e+02  4.534947e+02        2.129541e+01
# High       1.669159e+02  1.697100e+02  1.234000e+02  1.055500e+02  4.590339e+02        2.142508e+01
# Low        1.654222e+02  1.683000e+02  1.685200e+02  1.041600e+02  4.470812e+02        2.114430e+01
# Adj Close  1.661920e+02  1.690000e+02  1.786400e+02  1.046200e+02  4.535243e+02        2.129611e+01

# %% [markdown]
# # Histogram Chart

# %%
# Plotting a histogram of gold prices over time using the "Price" column
plt.figure(figsize=(15, 6))
plt.hist(df["Close"], bins=50, edgecolor="black", alpha=0.6, color='grey')
plt.title("Histogram chart of gold price")
plt.xlabel("Gold Price")
plt.ylabel("Frequency")
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# # Box Plot

# %%
plt.figure(figsize=(15, 6))

data = df['Close']

plt.boxplot(data, labels=['Box Plot of Gold Price'], patch_artist=True, boxprops=dict(facecolor='skyblue', color='blue'),)


plt.ylabel('Close')
# Out:
# C:\Users\yashi\AppData\Local\Temp\ipykernel_32244\948783023.py:5: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(data, labels=['Box Plot of Gold Price'], patch_artist=True, boxprops=dict(facecolor='skyblue', color='blue'),)
# Text(0, 0.5, 'Close')

# %% [markdown]
# # Scatter Plot

# %%
# Convert 'Date' column to datetime format
df['Date'] = pd.to_datetime(df['Date'])

# Plotting the scatter plot
plt.figure(figsize=(10, 6))
plt.scatter(df['Date'], df['Close'], s=5, alpha=0.6)  # Using small points for scatter plot effect
plt.title("Gold Prices Over Time (Scatter Plot)")
plt.xlabel("Date")
plt.ylabel("Price (USD)")
plt.grid(True)
plt.show()
