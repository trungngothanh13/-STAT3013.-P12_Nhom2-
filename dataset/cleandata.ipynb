# %%
import pandas as pd
import matplotlib as mlb

# %%
df = pd.read_csv('filtered_online_retail.csv')
df
# Out:
#         InvoiceNo StockCode                          Description  Quantity  \
# 0          536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1          536365     71053                  WHITE METAL LANTERN         6
# 2          536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3          536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4          536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...           ...       ...                                  ...       ...
# 391323     581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 391324     581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 391325     581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 391326     581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 391327     581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                 InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
non_product_keywords = 'postage|charges|fee|adjustment|refund|gift|sample'
non_product = df[df['Description'].str.contains(non_product_keywords, case=False, na=False)]
non_product
# Out:
#         InvoiceNo StockCode                     Description  Quantity  \
# 30         536370     21883                STARS GIFT TAPE         24
# 52         536373     37370      RETRO COFFEE MUGS ASSORTED         6
# 69         536375     37370      RETRO COFFEE MUGS ASSORTED         6
# 273        536396     37370      RETRO COFFEE MUGS ASSORTED         6
# 409        536406     37370      RETRO COFFEE MUGS ASSORTED         6
# ...           ...       ...                             ...       ...
# 390962     581496     23437   50'S CHRISTMAS GIFT BAG LARGE        12
# 391105     581538     23353  6 GIFT TAGS VINTAGE CHRISTMAS          1
# 391213     581578     22585       PACK OF 6 BIRDY GIFT TAGS        12
# 391232     581579     23353  6 GIFT TAGS VINTAGE CHRISTMAS         12
# 391278     581580     37500     TEA TIME TEAPOT IN GIFT BOX         1
#
#                 InvoiceDate  UnitPrice  CustomerID         Country
# ...
